# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.919560e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.688174e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.769071e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.782312e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552563e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.010663e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.694249e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.927028e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.137024e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.768627e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.170318e-16      1.020713   -4.797473     -0.762494
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize = (20,15))
sns.boxplot(data = df)
plt.show()

# %% [markdown]
# From the above graph we can see that the variables from V1 to V28 are standarized but Time and Amount are not standarized.

# %%
df['Class'].value_counts().plot.bar()
plt.show()

print((df['Class'].value_counts()) / df.shape[0]*100)
# Out:
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64

# %% [markdown]
# So from the above results we can clearly see that there is a imbalanced dataset because the percentage of 0 is about 99% and for 1 is about 0.17%

# %% [markdown]
# So treat to this imbalanced data we have three techniques they are:
#
# 1. Undersample Majority Class
#
# 2. Oversample Minority Class
#
# 3. SMOT (creating new data)--to that we can train new data, but will test it only on originally given data

# %%
from sklearn.preprocessing import StandardScaler
df1 = df[['Amount', 'Time']]
cols = df1.columns
ss = StandardScaler()
df1 = ss.fit_transform(df1)
df1 = pd.DataFrame(df1, columns = cols)

df2 = df.drop(columns = ['Amount', 'Time'])
df2 = pd.concat([df2, df1], axis = 1)
df2
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
cor = df2.corr()
plt.figure(figsize = (30,20))
ax = sns.heatmap(cor, annot = True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
X = df.drop(['Class'], axis = 1)
y = df['Class']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lr.predict(X_test)

# %%
print('Accuracy Score:', accuracy_score(y_test, y_pred))

print(confusion_matrix(y_test, y_pred))

print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.9990051847430451
# [[85278    30]
#  [   55    80]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85308
#            1       0.73      0.59      0.65       135
#
#     accuracy                           1.00     85443
#    macro avg       0.86      0.80      0.83     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve

def model_compare(lr,X_train,X_test,y_train,y_test):
    lr.fit(X_train,y_train)
    ypred_train = lr.predict(X_train)
    ypred_test = lr.predict(X_test)
    
    yprob_train = lr.predict_proba(X_train)[:,1]
    yprob_test = lr.predict_proba(X_test)[:,1]
    
    print('Accuracy on Train Set',accuracy_score(y_train,ypred_train))
    print('Accuracy on Test Set',accuracy_score(y_test,ypred_test))
    
    print('AUC ROC on Train Set',roc_auc_score(y_train,yprob_train))
    print('AUC ROC on Test Set',roc_auc_score(y_test,yprob_test))
    
    fpr,tpr,thresholds = roc_curve(y_test,yprob_test)
    plt.plot(fpr,tpr)
    plt.plot(fpr,fpr,'r-')
    plt.show()

# %%
model_compare(lr, X_train, X_test, y_train, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy on Train Set 0.9989717301017235
# Accuracy on Test Set 0.9990051847430451
# AUC ROC on Train Set 0.9236531085523096
# AUC ROC on Test Set 0.874166809938367

# %% [markdown]
# ## Undersample the Majority Class

# %%
print(len(y_train), len(y_test))

print(len(y_train[y_train == 1]), len(y_test[y_test == 1]))
# Out:
# 199364 85443
# 357 135

# %%
Xy_train = pd.concat([X_train, y_train], axis = 1)

Xy_train0 = Xy_train.loc[Xy_train['Class'] == 0]
Xy_train1 = Xy_train.loc[Xy_train['Class'] == 1]

len0 = len(Xy_train0)
len1 = len(Xy_train1)

Xy_train0_us = Xy_train0.sample(len1)

Xy_train_us = pd.concat([Xy_train0_us, Xy_train1], axis = 0)

X_train_us = Xy_train_us.drop(['Class'], axis = 1)
y_train_us = Xy_train_us['Class']

# %% [markdown]
# We undersample the majority class i.e. 0 to make equal to minority class i.e 1. This excersise was done only for train dataset Test data was untouch

# %%
lr1 = LogisticRegression()
model_compare(lr1, X_train_us, X_test, y_train_us, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy on Train Set 0.938375350140056
# Accuracy on Test Set 0.9810048804466135
# AUC ROC on Train Set 0.9725615736490675
# AUC ROC on Test Set 0.9446192359189968

# %% [markdown]
# ## Oversampling

# %%
Xy_train = pd.concat([X_train, y_train], axis = 1)

Xy_train0 = Xy_train.loc[Xy_train['Class'] == 0]
Xy_train1 = Xy_train.loc[Xy_train['Class'] == 1]

len0 = len(Xy_train0)
len1 = len(Xy_train1)

Xy_train1_os = Xy_train1.sample(len0, replace = True)

Xy_train_os = pd.concat([Xy_train1_os, Xy_train0], axis = 0)

X_train_os = Xy_train_os.drop(['Class'], axis = 1)
y_train_os = Xy_train_os['Class']

# %%
lr2 = LogisticRegression()
model_compare(lr2, X_train_os, X_test, y_train_os, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy on Train Set 0.9490646057676363
# Accuracy on Test Set 0.9758435448193532
# AUC ROC on Train Set 0.9781383166263756
# AUC ROC on Test Set 0.9621161837976203

# %% [markdown]
# ## Smoting

# %% [markdown]
# Smoting is nothing but the oversampling but not blindly multiplying to one's just creating the new data points

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy = 'minority')
X_train_sm, y_train_sm = smote.fit_sample(X_train, y_train)

# %%
lr3 = LogisticRegression()
model_compare(lr3, X_train_sm, X_test, y_train_sm, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy on Train Set 0.7312833216922018
# Accuracy on Test Set 0.7942136863171939
# AUC ROC on Train Set 0.7793134460380541
# AUC ROC on Test Set 0.6656289453987209
