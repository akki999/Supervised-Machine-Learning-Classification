# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('US_Heart_Patients.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.shape
# Out:
# (4240, 16)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
# male               4240 non-null int64
# age                4240 non-null int64
# education          4135 non-null float64
# currentSmoker      4240 non-null int64
# cigsPerDay         4211 non-null float64
# BPMeds             4187 non-null float64
# prevalentStroke    4240 non-null int64
# prevalentHyp       4240 non-null int64
# diabetes           4240 non-null int64
# totChol            4190 non-null float64
# sysBP              4240 non-null float64
# diaBP              4240 non-null float64
# BMI                4221 non-null float64
# heartRate          4239 non-null float64
# glucose            3852 non-null float64
# TenYearCHD         4240 non-null int64
# dtypes: float64(9), int64(7)
# memory usage: 530.1 KB

# %%
df['glucose'] = df['glucose'].fillna(method = 'ffill')

# %%
## We decided to fill missing values with ffill because filling with median is changing the distribution and reducing the variance.

# %%
df['glucose'].isnull().sum()
# Out:
# 0

# %%
sns.distplot(df['glucose'])
plt.show()

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose              0
# TenYearCHD           0
# dtype: int64

# %%
df = df.fillna(method = 'ffill')

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
plt.figure(figsize = (20,15))
sns.boxplot(data = df)
plt.show()

# %%
cols = list(df.columns)
for i in cols:
    sns.boxplot(df[i])
    plt.show()

# %%
q1 = df['totChol'].quantile(0.25)
q3 = df['totChol'].quantile(0.75)
iqr = q3 - q1
ul = q3 + 1.5 * iqr
ll = q3 - 1.5 * iqr
df = df[~(df['totChol'] > (q3+1.5*iqr))]
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4185.000000  4185.000000  4185.000000    4185.000000  4185.000000
# mean      0.432258    49.525926     1.983513       0.493668     9.041577
# std       0.495449     8.577526     1.021970       0.500020    11.963584
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4185.000000   4185.000000  4185.000000  4185.000000
# mean      0.028674         0.005974      0.307049     0.025329   234.761529
# std       0.166908         0.077068      0.461325     0.157140    40.921613
# ...

# %%
q1 = df['glucose'].quantile(0.25)
q3 = df['glucose'].quantile(0.75)
iqr = q3 - q1
ul = q3 + 1.5 * iqr
ll = q3 - 1.5 * iqr
df = df[~(df['glucose'] > (q3+1.5*iqr))]
df.describe()
# Out:
#               male         age    education  currentSmoker   cigsPerDay  \
# count  3990.000000  3990.00000  3990.000000    3990.000000  3990.000000
# mean      0.431328    49.35188     1.992732       0.494737     9.109023
# std       0.495324     8.55560     1.022042       0.500035    12.016905
# min       0.000000    32.00000     1.000000       0.000000     0.000000
# 25%       0.000000    42.00000     1.000000       0.000000     0.000000
# 50%       0.000000    48.00000     2.000000       0.000000     0.000000
# 75%       1.000000    56.00000     3.000000       1.000000    20.000000
# max       1.000000    70.00000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  3990.000000      3990.000000   3990.000000  3990.000000  3990.000000
# mean      0.026817         0.005514      0.299499     0.007519   234.599248
# std       0.161569         0.074059      0.458096     0.086395    40.855621
# ...

# %%
sns.boxplot(df['TenYearCHD'])
plt.show()

# %%
df['TenYearCHD'].value_counts(normalize = True)
# Out:
# 0    0.856391
# 1    0.143609
# Name: TenYearCHD, dtype: float64

# %%
df['TenYearCHD'].value_counts(normalize = True).plot.bar()
plt.show()

# %%
## The chart shows that 15% of the group had Heart Diseases

# %%
sns.pairplot(data = df, hue = 'TenYearCHD')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df1 = df.drop(columns = ['male', 'currentSmoker', 'BPMeds','prevalentStroke', 'prevalentHyp'])
df1
# Out:
#       age  education  cigsPerDay  diabetes  totChol  sysBP  diaBP    BMI  \
# 0      39        4.0         0.0         0    195.0  106.0   70.0  26.97
# 1      46        2.0         0.0         0    250.0  121.0   81.0  28.73
# 2      48        1.0        20.0         0    245.0  127.5   80.0  25.34
# 3      61        3.0        30.0         0    225.0  150.0   95.0  28.58
# 4      46        3.0        23.0         0    285.0  130.0   84.0  23.10
# ...   ...        ...         ...       ...      ...    ...    ...    ...
# 4235   48        2.0        20.0         0    248.0  131.0   72.0  22.00
# 4236   44        1.0        15.0         0    210.0  126.5   87.0  19.16
# 4237   52        2.0         0.0         0    269.0  133.5   83.0  21.47
# 4238   40        3.0         0.0         0    185.0  141.0   98.0  25.60
# 4239   39        3.0        30.0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# ...

# %%
sns.pairplot(data = df1, hue = 'TenYearCHD')
plt.show()

# %% [markdown]
# Pairplot shows that diagnol plots are univariate analysis and scatter plots off the diagnols.
# since we have used CHD as hue, the plots or color is split based on the hue.

# %%
sns.stripplot(x='TenYearCHD', y='glucose', data = df)
plt.show()

# %%
cols = list(df1.columns)

for i in cols:
    sns.boxplot(data = df1, x='TenYearCHD', y = i)
    plt.show()

# %% [markdown]
# ## Logistic Regression - BY Statistical Approach

# %%
import statsmodels.api as sm

# %%
y = df['TenYearCHD']
X = df.drop('TenYearCHD', axis = 1)

# %%
X = sm.add_constant(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model = sm.Logit(y, X)
result = model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.369112
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:             TenYearCHD   No. Observations:                 3990
# Model:                          Logit   Df Residuals:                     3974
# Method:                           MLE   Df Model:                           15
# Date:                Tue, 17 Dec 2019   Pseudo R-squ.:                  0.1029
# Time:                        11:27:55   Log-Likelihood:                -1472.8
# converged:                       True   LL-Null:                       -1641.7
# Covariance Type:            nonrobust   LLR p-value:                 6.929e-63
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
## Calculating VIF for all the variables

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
pd.DataFrame({'vif': vif}, index=X.columns).T
# Out:
#           const     male      age  education  currentSmoker  cigsPerDay  \
# vif  227.913559  1.19459  1.36957   1.052614       2.504259    2.635833
#
#        BPMeds  prevalentStroke  prevalentHyp  diabetes   totChol     sysBP  \
# vif  1.095756         1.024092      2.059013  1.006678  1.112827  3.707781
#
#         diaBP       BMI  heartRate   glucose
# vif  3.011302  1.228076   1.093935  1.029045

# %%
## Backward elimination to drop insignificant variables one by one

# %%
cols = list(X.columns)
p = []

while len(cols) > 1:
    X = X[cols]
    model = sm.Logit(y,X).fit().pvalues
    p = pd.Series(model.values[1:], index = X.columns[1:])
    pmax = max(p)
    pid = p.idxmax()
    if pmax > 0.05:
        cols.remove(pid)
        print('Variable Removed:', pid, pmax)
    else:
        break
cols
# Out:
# Optimization terminated successfully.
#          Current function value: 0.369112
#          Iterations 7
# Variable Removed: heartRate 0.8052013465671799
# Optimization terminated successfully.
#          Current function value: 0.369119
#          Iterations 7
# Variable Removed: education 0.7478524976069063
# Optimization terminated successfully.
#          Current function value: 0.369132
#          Iterations 7
# Variable Removed: glucose 0.7219396300324536
# Optimization terminated successfully.
#          Current function value: 0.369148
#          Iterations 7
# Variable Removed: currentSmoker 0.6940710478193599
# Optimization terminated successfully.
#          Current function value: 0.369167
#          Iterations 7
# Variable Removed: diaBP 0.6527901578944405
# Optimization terminated successfully.
#          Current function value: 0.369193
#          Iterations 7
# Variable Removed: diabetes 0.5718918323514135
# Optimization terminated successfully.
# ...

# %%
model1 = sm.Logit(y, X[cols])
result1 = model1.fit()
result1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.369782
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:             TenYearCHD   No. Observations:                 3990
# Model:                          Logit   Df Residuals:                     3984
# Method:                           MLE   Df Model:                            5
# Date:                Tue, 17 Dec 2019   Pseudo R-squ.:                  0.1013
# Time:                        11:27:55   Log-Likelihood:                -1475.4
# converged:                       True   LL-Null:                       -1641.7
# Covariance Type:            nonrobust   LLR p-value:                 9.736e-70
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# For Age Three conclusions
# 1)By looking sign of coeff of age we can say that as age increases CHD increases
# 2)As age increases by 1 log(odds) of CHD increases by 0.068.
# 3)As age increases by 1 odds of CHD increases by 7%.
#
# For Male:
# 1)By looking the sign of coeff of male we can say that compare to female male got higher chance of CHD.
# 2)If it is male log(odds) of CHD for male is 0.4770 higher than male
# 3)Male got 61% chance of getting CHD than female.
#
# For cigsperday:
# 1)By looking sign of coeff of Cigsperday we can say that as Cigsperday increases CHD increases.
# 2)As Cigsperday increases by 1 log(odds) of CHD increases by 0.0221.
# 3)As Cigsperday increases by 1 odds of CHD increases by 2.2%

# %%
np.exp(result1.pvalues)
# Out:
# const              1.000000
# male               1.000003
# age                1.000000
# cigsPerDay         1.000000
# prevalentStroke    1.045490
# sysBP              1.000000
# dtype: float64

# %%
np.exp(result1.params)
# Out:
# const              0.000326
# male               1.614625
# age                1.070137
# cigsPerDay         1.022308
# prevalentStroke    2.581632
# sysBP              1.017153
# dtype: float64

# %%
df.to_csv('cleanheart.csv')

# %%
## It gives u the coeffiecents.
result1.params
# Out:
# const             -8.027279
# male               0.479103
# age                0.067786
# cigsPerDay         0.022062
# prevalentStroke    0.948422
# sysBP              0.017008
# dtype: float64

# %%
prob = result1.predict(X[cols])

# %%
prob
# Out:
# 0       0.043039
# 1       0.054623
# 2       0.156479
# 3       0.336432
# 4       0.100595
#           ...
# 4235    0.108686
# 4236    0.071609
# 4237    0.096930
# 4238    0.080277
# 4239    0.078734
# Length: 3990, dtype: float64

# %%
prob = result1.predict(X[cols])
prob = pd.DataFrame(prob, columns=['prob'])
prob['y_est'] = prob['prob'].apply(lambda x: 1 if x>=0.5 else 0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
confusion_matrix(y, prob['y_est'])
# Out:
# array([[3396,   21],
#        [ 545,   28]], dtype=int64)

# %%
accuracy_score(y, prob['y_est'])
# Out:
# 0.8581453634085213

# %%
print(classification_report(y, prob['y_est']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      3417
#            1       0.57      0.05      0.09       573
#
#     accuracy                           0.86      3990
#    macro avg       0.72      0.52      0.51      3990
# weighted avg       0.82      0.86      0.80      3990

# %% [markdown]
# ## Logistic Regression By a Machine Learning

# %%
X = df.drop(columns = 'TenYearCHD')
y = df['TenYearCHD']

# %%
X.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(solver = 'liblinear', fit_intercept = True)

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_prob = logreg.predict_proba(X_test)
y_prob[:,1]
# Out:
# array([0.12489078, 0.04021046, 0.089476  , ..., 0.24755034, 0.24810836,
#        0.06303727])

# %%
y_pred = logreg.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8521303258145363

# %%
## For test data

# %%
y_prob_train = logreg.predict_proba(X_train)
y_prob_train[:,1]
# Out:
# array([0.05524661, 0.09971392, 0.08725848, ..., 0.11442629, 0.05693443,
#        0.04042409])

# %%
y_pred_train = logreg.predict(X_train)
y_pred_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_prob_test = logreg.predict_proba(X_test)
y_prob_test[:,1]
# Out:
# array([0.12489078, 0.04021046, 0.089476  , ..., 0.24755034, 0.24810836,
#        0.06303727])

# %%
y_pred_test = logreg.predict(X_test)
y_pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
print('Confusion Matrix - Train:', '\n', confusion_matrix(y_train, y_pred_train))
print('Overall Accuracy', accuracy_score(y_train, y_pred_train))
# Out:
# Confusion Matrix - Train:
#  [[2387   11]
#  [ 380   15]]
# Overall Accuracy 0.8600071607590405

# %%
print('Confusion Matrix - Test:', '\n', confusion_matrix(y_test, y_pred_test))
print('Overall Accuracy', accuracy_score(y_test, y_pred_test))
# Out:
# Confusion Matrix - Test:
#  [[1016    3]
#  [ 174    4]]
# Overall Accuracy 0.8521303258145363

# %%
y_prob_train
# Out:
# array([[0.94475339, 0.05524661],
#        [0.90028608, 0.09971392],
#        [0.91274152, 0.08725848],
#        ...,
#        [0.88557371, 0.11442629],
#        [0.94306557, 0.05693443],
#        [0.95957591, 0.04042409]])

# %%
y_prob_train = logreg.predict_proba(X_train)[:,-1]
prob_plot = pd.DataFrame([y_prob_train, y_train]).T

# %%
prob_plot.head()
# Out:
#           0    1
# 0  0.055247  0.0
# 1  0.099714  0.0
# 2  0.087258  0.0
# 3  0.024554  0.0
# 4  0.080174  0.0

# %%
sns.kdeplot(prob_plot[0][prob_plot[1] == 0])
sns.kdeplot(prob_plot[0][prob_plot[1] == 1])
plt.show()

# %% [markdown]
# The above chart shows the distributions of predicted probability separately for target(CHD)-0 and target(CHD)-1

# %% [markdown]
# ## ROC Analysis

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(solver = 'liblinear', fit_intercept = True)

logreg.fit(X_train, y_train)

y_prob_train = logreg.predict_proba(X_train)[:,1] 
y_pred_train = logreg.predict(X_train)

y_prob_test = logreg.predict_proba(X_test)[:,1] 
y_pred_test = logreg.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score, roc_curve

print('AUC of Train:', roc_auc_score(y_train, y_prob_train))

fpr, tpr, thresholds = roc_curve(y_train, y_prob_train)


plt.plot(fpr, tpr)
plt.plot(fpr,fpr, 'r-')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()
# Out:
# AUC of Train: 0.7414776026435532

# %%
print('AUC of Train:', roc_auc_score(y_test, y_prob_test))

fpr, tpr, thresholds = roc_curve(y_test, y_prob_test)


plt.plot(fpr, tpr)
plt.plot(fpr,fpr, 'r-')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC for Test Data')
plt.show()
# Out:
# AUC of Train: 0.6758498638233121

# %%
thresholds[thresholds > 1] = 1

# %%
thresholds
# Out:
# array([1.        , 0.78377409, 0.6935795 , 0.65914805, 0.63977137,
#        0.63922861, 0.62815391, 0.61749214, 0.5324857 , 0.52920962,
#        0.52791323, 0.5259759 , 0.52485352, 0.51383646, 0.51291857,
#        0.50648726, 0.50109476, 0.48885103, 0.48360538, 0.48278995,
#        0.47633396, 0.47470449, 0.46720439, 0.46459386, 0.4607368 ,
#        0.455369  , 0.45020867, 0.44807677, 0.44589407, 0.44548008,
#        0.44545281, 0.44497707, 0.44236987, 0.42228237, 0.42119449,
#        0.42000805, 0.41952573, 0.41630297, 0.41590975, 0.40854174,
#        0.40624825, 0.40580193, 0.40375598, 0.40031879, 0.39887633,
#        0.39885067, 0.39878231, 0.39644747, 0.39373736, 0.39293101,
#        0.39118798, 0.38925255, 0.38916746, 0.38674342, 0.38581925,
#        0.38260684, 0.38030172, 0.37895854, 0.37732532, 0.36527573,
#        0.36334276, 0.35890951, 0.35866339, 0.35172109, 0.35117675,
#        0.34993294, 0.34968693, 0.34689586, 0.3458919 , 0.33894263,
# ...

# %%
print('AUC of Train:', roc_auc_score(y_train, y_prob_train))
plt.plot(fpr, tpr)
plt.plot(fpr,fpr, 'r-')
plt.plot(fpr, thresholds)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()
# Out:
# AUC of Train: 0.7414776026435532

# %%
print('AUC of train: ', roc_auc_score(y_train, y_prob_train)) #for train data

fig, ax = plt.subplots()

ax.plot(fpr, tpr) #blue color
ax.plot(fpr, fpr, 'r-') #red color
plt.xlabel('FPR')
plt.ylabel('TPR')
ax1 = ax.twinx()
ax1.plot(fpr,thresholds) #orange color 


plt.title('ROC_Curve of Train data')
plt.show()
# Out:
# AUC of train:  0.7414776026435532
